# %%
from pathlib import Path
from ultralytics import YOLO
import numpy as np

# %%
def iou_calculator(box1, box2):                                                     

    x1, y1, width_1, height_1 = box1 [1], box1 [2], box1 [3], box1 [4]                
    x2, y2, width_2, height_2 = float(box2 [1]), float(box2 [2]), float(box2 [3]), float(box2 [4])

    x_left = max(x1 - width_1 / 2, x2 - width_2 / 2)                                # Calculating coordinates of intersection rectangle
    y_top = max(y1 - height_1 / 2, y2 - height_2 / 2)
    x_right = min(x1 + width_1 / 2, x2 + width_2 / 2)
    y_bottom = min(y1 + height_1 / 2, y2 + height_2 / 2)
    
    intersection_area = max(0, x_right - x_left) * max(0, y_bottom - y_top)         # Calculating area of intersection rectangle
    
    box1_area = width_1 * height_1                                                    # Calculating area of both bounding boxes
    box2_area = width_2 * height_2
    
    union_area = box1_area + box2_area - intersection_area                          # Calculating union area
    
    if union_area == 0:                                                              
        iou = 0  # Avoid division by zero
    else:
        iou = intersection_area / union_area
    
    return iou

# %%
def confusion_matrix_calculator_for_oneframe(list_of_gt_boxes, list_of_pred_boxes, iou_threshold):         #Confusion_matrix_calculator for singel frame
    box_local_TP = 0  
    box_local_FP = 0 
    box_local_FN = 0  

    class_local_TP = 0  
    class_local_FP = 0 
    class_local_FN = 0  

    for actual_box in list_of_gt_boxes:
        for pred_box in list_of_pred_boxes:
            gt_matched_box = False
            gt_matched_class = False                                                 # Flags to check the match
            
            iou = iou_calculator(actual_box, pred_box)                               # Calculatig IoU between ground truth box and predicted box
            if iou >= iou_threshold:
                box_local_TP += 1
                gt_matched_box = True
                if actual_box[0] == actual_box[0]:
                     class_local_TP += 1
                     gt_matched_class = True  
                break                 
        if not gt_matched_box:                                                   # If ground truth box is not matched with any predicted box, consider it a false negative
            box_local_FN += 1
        if not gt_matched_class:
            class_local_FN += 1

    box_local_FP = len(list_of_pred_boxes) - box_local_TP
    class_local_FP = len(list_of_pred_boxes) - class_local_TP


    return box_local_TP, box_local_FP, box_local_FN, class_local_TP, class_local_FP, class_local_FN

# %%
def class_box_generator_for_gt(txt_file):
    list_of_detections_gt = []
    with open(txt_file, 'r') as file:
        for line in file:
            detection = line.strip().split()
            list_of_detections_gt.append(detection)
    return list_of_detections_gt

# %%
def class_box_generator_for_pred(prediction_results):

    for result in prediction_results:
        list_of_pred_boxes = []
        pred_class_list = result.boxes.cls.tolist()
        box_array = result.boxes.xywhn.tolist()
        
        for detection in box_array:
            detection_data = np.append(pred_class_list[box_array.index(detection)], detection)
            list_of_pred_boxes.append(detection_data)
      
        return list_of_pred_boxes

# %%
def precision_recall_calculator(path_to_test_images, path_to_gt_txts):

    model = YOLO('yolov8s.pt')

    list_of_images = list(image for image in (path_to_test_images.iterdir()))
    list_of_gt_txts = list(json for json in (path_to_gt_txts.iterdir()))

    list_of_images.sort()
    list_of_gt_txts.sort()

    combined_box_TP = 0                 #for all frames                                                                    
    combined_box_FP = 0 
    combined_box_FN = 0  


    combined_class_TP = 0             #for all frames                                                               
    combined_class_FP = 0 
    combined_class_FN = 0 


    for image in list_of_images:
        gt_txt = list_of_gt_txts[list_of_images.index(image)]
        list_of_gt_boxes = class_box_generator_for_gt(gt_txt)
        
        results = model.predict(image, save=True)
        list_of_pred_boxes = class_box_generator_for_pred(results)
        

        #BBOX C-Matrix Recording 
        box_local_TP, box_local_FP, box_local_FN, class_local_TP, class_local_FP, class_local_FN = confusion_matrix_calculator_for_oneframe(list_of_pred_boxes, list_of_gt_boxes, iou_threshold=0.8)

        combined_box_TP += box_local_TP
        combined_box_FP += box_local_FP
        combined_box_FN += box_local_FN

        combined_class_TP += class_local_TP
        combined_class_FP += class_local_FP
        combined_class_FN += class_local_FN


    bbox_precision = combined_box_TP / (combined_box_TP + combined_box_FP) if (combined_box_TP + combined_box_FP) > 0 else 0                     
    bbox_recall = combined_box_TP / (combined_box_TP + combined_box_FN) if (combined_box_TP + combined_box_FN) > 0 else 0

    class_precision = combined_class_TP / (combined_class_TP + combined_class_FP) if (combined_class_TP + combined_class_FP) > 0 else 0                    
    class_recall = combined_class_TP / (combined_class_TP + combined_class_FN) if (combined_class_TP + combined_class_FN) > 0 else 0
    
    print(f'bbox precision: {bbox_precision * 100}%, bbox_recall {bbox_recall}')
    print(f'class precision: {class_precision * 100}%, class_recall {class_recall}')

# %%
path_to_test_images = Path(r'C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data')
path_to_gt_txts = Path(r'C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\labels')

precision_recall_calculator(path_to_test_images, path_to_gt_txts)
# Out:
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-14-905.png: 416x640 1 person, 2 cars, 466.5ms
# Speed: 0.0ms preprocess, 466.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-14-972.png: 416x640 1 person, 2 cars, 434.8ms
# Speed: 5.0ms preprocess, 434.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-15-005.png: 416x640 1 person, 1 car, 431.6ms
# Speed: 17.1ms preprocess, 431.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-15-305.png: 416x640 1 person, 1 car, 515.3ms
# Speed: 34.4ms preprocess, 515.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-15-405.png: 416x640 1 person, 2 cars, 382.3ms
# Speed: 0.0ms preprocess, 382.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-15-505.png: 416x640 1 person, 1 car, 365.5ms
# Speed: 0.0ms preprocess, 365.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-15-572.png: 416x640 3 persons, 1 car, 498.3ms
# Speed: 3.6ms preprocess, 498.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-15-605.png: 416x640 1 person, 2 cars, 383.3ms
# Speed: 3.8ms preprocess, 383.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-15-805.png: 416x640 1 person, 2 cars, 398.7ms
# Speed: 0.0ms preprocess, 398.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-15-872.png: 416x640 1 person, 1 car, 451.9ms
# Speed: 15.0ms preprocess, 451.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-15-905.png: 416x640 1 person, 1 car, 564.9ms
# Speed: 15.7ms preprocess, 564.9ms inference, 3.3ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-16-072.png: 416x640 1 person, 1 car, 415.6ms
# Speed: 0.0ms preprocess, 415.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-16-105.png: 416x640 1 person, 1 car, 452.2ms
# Speed: 16.3ms preprocess, 452.2ms inference, 16.6ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-16-172.png: 416x640 1 person, 1 car, 536.5ms
# Speed: 4.0ms preprocess, 536.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-16-205.png: 416x640 1 person, 2 cars, 565.5ms
# Speed: 0.0ms preprocess, 565.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-16-239.png: 416x640 1 person, 2 cars, 516.5ms
# Speed: 0.0ms preprocess, 516.5ms inference, 15.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-16-305.png: 416x640 1 person, 2 cars, 515.1ms
# Speed: 0.0ms preprocess, 515.1ms inference, 16.5ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-16-372.png: 416x640 1 person, 1 car, 597.2ms
# Speed: 0.0ms preprocess, 597.2ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-16-405.png: 416x640 1 person, 1 car, 500.7ms
# Speed: 0.0ms preprocess, 500.7ms inference, 14.8ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-16-505.png: 416x640 1 person, 2 cars, 400.2ms
# Speed: 0.0ms preprocess, 400.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-16-672.png: 416x640 1 person, 2 cars, 434.7ms
# Speed: 0.0ms preprocess, 434.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-16-705.png: 416x640 1 person, 1 car, 379.9ms
# Speed: 0.0ms preprocess, 379.9ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-16-772.png: 416x640 2 cars, 421.3ms
# Speed: 0.0ms preprocess, 421.3ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-16-872.png: 416x640 1 car, 457.9ms
# Speed: 11.2ms preprocess, 457.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-16-905.png: 416x640 1 car, 518.2ms
# Speed: 31.8ms preprocess, 518.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-16-972.png: 416x640 2 cars, 468.8ms
# Speed: 0.0ms preprocess, 468.8ms inference, 16.1ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-17-005.png: 416x640 2 cars, 441.0ms
# Speed: 5.0ms preprocess, 441.0ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-17-072.png: 416x640 1 car, 459.4ms
# Speed: 3.0ms preprocess, 459.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-17-172.png: 416x640 1 car, 548.1ms
# Speed: 0.0ms preprocess, 548.1ms inference, 18.9ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-17-205.png: 416x640 1 car, 365.4ms
# Speed: 5.9ms preprocess, 365.4ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-17-305.png: 416x640 1 car, 416.7ms
# Speed: 0.0ms preprocess, 416.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-17-372.png: 416x640 1 car, 590.8ms
# Speed: 0.0ms preprocess, 590.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-17-505.png: 416x640 2 cars, 401.5ms
# Speed: 0.0ms preprocess, 401.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-17-572.png: 416x640 2 cars, 390.8ms
# Speed: 3.0ms preprocess, 390.8ms inference, 5.7ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-17-772.png: 416x640 1 person, 1 car, 480.3ms
# Speed: 0.0ms preprocess, 480.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-17-872.png: 416x640 1 car, 544.6ms
# Speed: 0.0ms preprocess, 544.6ms inference, 5.6ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-18-005.png: 416x640 1 car, 529.8ms
# Speed: 2.9ms preprocess, 529.8ms inference, 3.5ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-18-072.png: 416x640 1 car, 507.8ms
# Speed: 4.0ms preprocess, 507.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-18-105.png: 416x640 2 cars, 535.0ms
# Speed: 49.9ms preprocess, 535.0ms inference, 14.9ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-18-172.png: 416x640 1 car, 461.0ms
# Speed: 4.0ms preprocess, 461.0ms inference, 15.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-18-405.png: 416x640 2 persons, 1 car, 1 motorcycle, 378.1ms
# Speed: 4.0ms preprocess, 378.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-18-472.png: 416x640 2 persons, 1 car, 401.7ms
# Speed: 0.0ms preprocess, 401.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-18-672.png: 416x640 1 person, 1 car, 472.2ms
# Speed: 0.0ms preprocess, 472.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-18-705.png: 416x640 1 person, 1 car, 376.6ms
# Speed: 0.0ms preprocess, 376.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-18-772.png: 416x640 2 persons, 1 car, 1 motorcycle, 376.2ms
# Speed: 0.0ms preprocess, 376.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-18-905.png: 416x640 2 persons, 1 car, 1 motorcycle, 486.4ms
# Speed: 46.9ms preprocess, 486.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-18-972.png: 416x640 2 persons, 1 car, 1 motorcycle, 389.3ms
# Speed: 0.0ms preprocess, 389.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-19-005.png: 416x640 2 persons, 1 car, 1 motorcycle, 378.7ms
# Speed: 0.0ms preprocess, 378.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-19-205.png: 416x640 3 persons, 1 car, 454.7ms
# Speed: 0.0ms preprocess, 454.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-19-272.png: 416x640 2 persons, 1 car, 375.7ms
# Speed: 10.5ms preprocess, 375.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-19-305.png: 416x640 2 persons, 1 car, 392.2ms
# Speed: 0.0ms preprocess, 392.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-19-572.png: 416x640 3 persons, 1 car, 455.1ms
# Speed: 0.0ms preprocess, 455.1ms inference, 15.6ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-19-605.png: 416x640 3 persons, 1 car, 423.5ms
# Speed: 47.3ms preprocess, 423.5ms inference, 15.6ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-19-805.png: 416x640 3 persons, 1 car, 376.6ms
# Speed: 15.6ms preprocess, 376.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-19-872.png: 416x640 2 persons, 1 car, 454.2ms
# Speed: 3.0ms preprocess, 454.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-20-105.png: 416x640 2 persons, 1 car, 376.7ms
# Speed: 0.0ms preprocess, 376.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-20-172.png: 416x640 2 persons, 1 car, 376.3ms
# Speed: 0.0ms preprocess, 376.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-20-305.png: 416x640 3 persons, 1 truck, 439.1ms
# Speed: 0.0ms preprocess, 439.1ms inference, 15.6ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-20-372.png: 416x640 1 person, 1 car, 627.3ms
# Speed: 15.6ms preprocess, 627.3ms inference, 15.6ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-20-472.png: 416x640 1 person, 1 car, 721.0ms
# Speed: 15.6ms preprocess, 721.0ms inference, 15.6ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-20-505.png: 416x640 1 person, 1 car, 517.6ms
# Speed: 0.0ms preprocess, 517.6ms inference, 15.6ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-20-539.png: 416x640 1 person, 1 car, 517.1ms
# Speed: 0.0ms preprocess, 517.1ms inference, 15.6ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-20-672.png: 416x640 2 persons, 1 car, 486.0ms
# Speed: 0.0ms preprocess, 486.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-20-705.png: 416x640 2 persons, 1 car, 486.4ms
# Speed: 0.0ms preprocess, 486.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-20-772.png: 416x640 2 persons, 1 car, 376.7ms
# Speed: 15.6ms preprocess, 376.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-20-805.png: 416x640 2 persons, 1 car, 454.6ms
# Speed: 15.6ms preprocess, 454.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-20-905.png: 416x640 3 persons, 2 cars, 565.0ms
# Speed: 0.0ms preprocess, 565.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-20-972.png: 416x640 3 persons, 2 cars, 408.3ms
# Speed: 0.0ms preprocess, 408.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-21-005.png: 416x640 3 persons, 2 cars, 455.1ms
# Speed: 0.0ms preprocess, 455.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-21-072.png: 416x640 1 person, 2 cars, 376.1ms
# Speed: 0.0ms preprocess, 376.1ms inference, 15.6ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-21-139.png: 416x640 1 person, 3 cars, 405.3ms
# Speed: 3.0ms preprocess, 405.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-21-205.png: 416x640 1 person, 3 cars, 455.1ms
# Speed: 0.0ms preprocess, 455.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-21-272.png: 416x640 2 persons, 3 cars, 407.3ms
# Speed: 0.0ms preprocess, 407.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-21-305.png: 416x640 2 persons, 1 car, 501.0ms
# Speed: 36.8ms preprocess, 501.0ms inference, 11.5ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-21-372.png: 416x640 2 persons, 3 cars, 423.0ms
# Speed: 15.6ms preprocess, 423.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-21-572.png: 416x640 1 person, 1 car, 414.9ms
# Speed: 9.0ms preprocess, 414.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-21-605.png: 416x640 1 person, 1 car, 548.8ms
# Speed: 0.0ms preprocess, 548.8ms inference, 15.6ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-21-672.png: 416x640 2 persons, 1 car, 831.7ms
# Speed: 31.2ms preprocess, 831.7ms inference, 15.6ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-21-805.png: 416x640 2 persons, 1 car, 627.8ms
# Speed: 15.6ms preprocess, 627.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\hussa\OneDrive\Desktop\Project\Dataset\INFRA-3DRC_scene-4\INFRA-3DRC_scene-4\camera_01\camera_01__data\camera_01__2023-07-06-20-05-21-872.png: 416x640 2 persons, 1 car, 959.3ms
# Speed: 0.0ms preprocess, 959.3ms inference, 185.3ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict
# bbox precision: 61.875%, bbox_recall 0.4604651162790698
# class precision: 61.875%, class_recall 0.4604651162790698
